# %% [markdown]
# ## EXO 1

# %% [markdown]
# #### Q1. Implémentez l’inversion modulo p (via l’algorithme d’Euclide étendu).

# %%
from random import random


def euclide_etendu(a, b):
    if b == 0:
        return a, 1, 0
    pgcd, u1, v1 = euclide_etendu(b, a % b)
    u = v1
    v = u1 - (a // b) * v1
    return pgcd, u, v

def inverse_mod(a, p):
    pgcd, x, _ = euclide_etendu(a % p, p)
    if pgcd != 1:
        raise ValueError(f"{a} pas inversible modulo {p}")
    return x % p

# %% [markdown]
# #### Q2. Implémentez un crible pour construire la liste des nombres premiers inférieurs à une certaine borne. L’algorithme classique est le suivant : partir d’un tableau de taille n, et marquer les cases multiples de i où i > 1 est le numéro de la plus petite case non marquée. À la fin, les cases non marquées sont aux positions premières. Générez la liste des premiers jusqu’à 1 000 000 et stockez la dans un fichier

# %%
def crible(n):
    p = [True]*(n+1) #ou n ?
    p[0] = False
    p[1] = False

    #on commence à i=2
    i=2
    while i*i <= n : #on s'arrête à la racine de n, car après la liste des diviseurs est symétrique
        if p[i]:
            for j in range(i*i, n+1, i):
                p[j] = False
        i+=1

    premiers = [i for i in range(n+1) if p[i]]
    return premiers

# %%
#Génération des premiers jusqu'à 1000000 et stockage dans premiers.txt

premiers = crible(1000000)

with open("premiers.txt", "w") as f:
    for p in premiers:
        f.write(str(p) + "\n")

# %% [markdown]
# #### Q3. Implémentez un test de primalité

# %%
def est_premier(n):
    if n<2:
        return False
    if n==2:
        return True
    if n%2==0:
        return False

    i = 3
    while i*i <= n:
        if n%i == 0:
            return False
        i+=2 #on saute les pairs
    return True

# %%
print(est_premier(98)) # false : 98 = 2*7*7
print(est_premier(7)) #True
# Out:
# False
# True

# %% [markdown]
# #### Q4. Implémentez calcul des diviseurs premiers d’un entier donné.

# %%
def diviseur_premier(n):
    diviseurs = []

    if n%2==0:
        diviseurs.append(2)
        while n%2==0:
            n = n//2

    i=3
    while i*i <= n:
        if n%i == 0:
            diviseurs.append(i)
            while n%i == 0:
                n = n//i
        i+=2

    if n>1:
        diviseurs.append(n)
    return diviseurs

# %%
print(diviseur_premier(360)) #[2,3,5]
# Out:
# [2, 3, 5]

# %% [markdown]
# #### Q5. Implémentez le calcul d’un générateur de Z/pZ∗. Vous pouvez tirer un élément au hasard tant que vous ne trouvez pas de générateur.

# %%
import random

def est_generateur(g, p, fact_premier):
    """Verifie si g est un générateur de Z/pZ*"""
    for q in fact_premier: #où fact_premier est les facteurs premiers de p-1
        if pow(g, (p-1)//q, p)==1:
            return False
    return True

def find_gen(p):
    """Trouve un générateur de Z/pZ* par tirage aléatoire"""
    facteurs = diviseur_premier(p-1)
    while True:
        g=random.randint(2,p-1)
        if est_generateur(g, p, facteurs):
            return g

#p=7
#g=find_gen(p)
#print(f"Générateur de Z/{p}Z* : {g}")

#pour vérifier, on affiche les puissances
#for i in range(1, p):
    #print(f"  {g}^{i} mod {p} = {pow(g, i, p)}")

# %% [markdown]
# #### Q6. Implémentez l’exponentiation modulo un nombre premier.

# %%
def exp_mod(g, x,p):
    """calcul efficace de g^x mod p"""

    result = 1
    g = g%p #pour le cas où g>=p

    while x>0:
        if x%2==1:
            result = (result * g) % p
        g=(g*g)%p
        x=x//2

    return result

# %%
print(exp_mod(3, 100, 17))   # 3^100 mod 17
# Out:
# 1
